# %% [markdown]
# # Part 2: Phrase-structure parsing with CKY
#
# In this part of the assignment, we'll train a simple phrase-structure (constituency) parser on the [Penn Treebank](https://catalog.ldc.upenn.edu/ldc99t42), then implement exact inference using the CKY algorithm.
#
# You may want to refer to the Week 10 async material and lecture notes for a detailed discussion of the algorithm. The following may also be useful:
# - [Guide to Penn Treebank constituent tags](http://www.surdeanu.info/mihai/teaching/ista555-fall13/readings/PennTreebankConstituents.html) - explains what `JJ`, `NNP`, and all the other tags mean.
# - [Syntactic Parsing (Jurafsky & Martin, Ch. 12)](https://web.stanford.edu/~jurafsky/slp3/12.pdf) - particularly 12.1 and 12.2.
# - [Accurate Unlexicalized Parsing](http://ilpubs.stanford.edu:8091/~klein/unlexicalized-parsing.pdf) (Klein & Manning, 2003)
#
# We'll write code in three parts:
# - **(a)** Initial preprocessing of the treebank
# - **(b)** Calculation of production rule probabilities
# - **(c)** Implementation of CKY algorithm
#
# We provide the code for 1 and much of the framework surrounding 2 and 3.

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /home/jay/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: pyparsing>=2.0.1 in /home/jay/anaconda2/lib/python2.7/site-packages (from pydotplus)

# %%
# Import some useful libraries...
import os
import sys
import collections
import copy
import unittest
import numpy as np
import nltk
from nltk.tree import Tree
from IPython.display import display, HTML

import logging
logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

# Helpers for this assignment
import part2_helpers
import treeviz
import pcfg, pcfg_test
import cky, cky_test

# Use the sample of the Penn Treebank included with NLTK.
assert(nltk.download('treebank'))
corpus = nltk.corpus.treebank

# If you do install the full Penn Treebank, change the "False" to "True" below.
use_full_ptb = False
if use_full_ptb:
    part2_helpers.verify_ptb_install()
    corpus = nltk.corpus.ptb  # Throws errors, for some reason
    # This configures the corpus to use the WSJ section only.
    # The Brown section has some mis-bracketed trees that will cause the 
    # corpus reader to throw (many) errors.
    if not hasattr(corpus, '_parsed_sents'):
        print "Monkey-patching corpus reader..."
        corpus._parsed_sents = corpus.parsed_sents
        corpus.parsed_sents = lambda: corpus._parsed_sents(categories=['news'])
# Out:
# [nltk_data] Downloading package treebank to /home/jay/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %% [markdown]
# `nltk` includes a tree drawing API, but it doesn't play nicely with SSH. We've implemented a version that uses PyDot and GraphViz, and should work on Google Cloud or any other remote server. To get it working, run the following from a terminal:
#
# ```
# sudo apt-get install graphviz
# pip install pydotplus
# ```
#
# You should also install the [`tqdm`](https://pypi.python.org/pypi/tqdm) package, which gives progress bars. Run the cell below:

# %%
# !pip install tqdm
from tqdm import tqdm as ProgressBar
# Out:
# Requirement already satisfied: tqdm in /home/jay/anaconda2/lib/python2.7/site-packages

# %%
# Monkey-patch NLTK
# This overrides the normal Tree display if running on Cloud or other display-less server.
# if not os.getenv("DISPLAY"):
#     print "Display-less server detected!"
print "Overriding nltk.tree.Tree pretty-printing to use custom GraphViz."
nltk.tree.Tree._repr_png_ = lambda _: None
nltk.tree.Tree._repr_html_ = lambda self: treeviz.render_tree(self, title=treeviz.make_title(self),
                                                             format='png')

corpus.parsed_sents()[35]
# Out:
# Overriding nltk.tree.Tree pretty-printing to use custom GraphViz.
# Tree('S', [Tree('NP-SBJ', [Tree('NN', ['Compound']), Tree('NNS', ['yields'])]), Tree('VP', [Tree('VBP', ['assume']), Tree('UCP', [Tree('NP', [Tree('NP', [Tree('NN', ['reinvestment'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNS', ['dividends'])])])]), Tree('CC', ['and']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['the']), Tree('JJ', ['current']), Tree('NN', ['yield'])]), Tree('VP', [Tree('VBZ', ['continues']), Tree('PP-TMP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['year'])])])])])])])]), Tree('.', ['.'])])

# %% [markdown]
# ## Part (a) Exercises: API warm-up
#
# We'll be using `nltk.tree.Tree` objects in the rest of the assignment, which provide some convenient methods for viewing and traversing parse trees, as well as extracting grammar rules (productions).
#
# The API is documented here: http://www.nltk.org/api/nltk.html#nltk.tree.Tree
#
# In the cells below, do the following to familiarize yourself with the Tree API:
#
# 1. Construct the tree `(S (NP foo) (VP bar))` using the Tree API. The constructor can be called as: `Tree(lhs, [rhs_1, rhs_2, ...]` where `lhs` is a string and `rhs_*` are either trees or strings.
# 2. Display the tree for the first sentence in the corpus. (It should be: "Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .")
# 3. For the first sentence, print the label of the root node and the labels of its immediate children.
# 4. For the first sentence, print all the productions in the sentence. Also print the LHS of the first production, and the RHS of the second production.

# %%
## Part (a).1
#### YOUR CODE HERE ####
t = Tree.fromstring("(S (NP foo) (VP bar))")

print type(t)
print t

#### END(YOUR CODE) ####
# Out:
# <class 'nltk.tree.Tree'>
# (S (NP foo) (VP bar))

# %%
## Part (a).2
#### YOUR CODE HERE ####
corpus.parsed_sents()[0]
#print corpus.parsed_sents()[0]
#### END(YOUR CODE) ####
# Out:
# Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['Pierre']), Tree('NNP', ['Vinken'])]), Tree(',', [',']), Tree('ADJP', [Tree('NP', [Tree('CD', ['61']), Tree('NNS', ['years'])]), Tree('JJ', ['old'])]), Tree(',', [','])]), Tree('VP', [Tree('MD', ['will']), Tree('VP', [Tree('VB', ['join']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['board'])]), Tree('PP-CLR', [Tree('IN', ['as']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nonexecutive']), Tree('NN', ['director'])])]), Tree('NP-TMP', [Tree('NNP', ['Nov.']), Tree('CD', ['29'])])])]), Tree('.', ['.'])])

# %%
## Part (a).3
#### YOUR CODE HERE ####
s = corpus.parsed_sents()[0]

print "The root label is " + s.label()
print '\n'

print "The sentence root has " + str(len(s)) + " children:"
print s[0].label()
print s[1].label()
print s[2].label()
print '\n'


#### END(YOUR CODE) ####
# Out:
# The root label is S
#
#
# The sentence root has 3 children:
# NP-SBJ
# VP
# .

# %%
## Part (a).4
#### YOUR CODE HERE ####
s = corpus.parsed_sents()[0]

print "There are " + str(len(s.productions())) + " productions:" + str(s.productions())

print '\nFirst production...'
print s.productions()[0]
print '\nLeft hand side of first production...'
print s.productions()[0].lhs()
print '\nSecond production...'
print s.productions()[1]
print '\nRight hand side of second production...'
print s.productions()[1].rhs()
print '\n'

#### END(YOUR CODE) ####
# Out:
# There are 29 productions:[S -> NP-SBJ VP ., NP-SBJ -> NP , ADJP ,, NP -> NNP NNP, NNP -> 'Pierre', NNP -> 'Vinken', , -> ',', ADJP -> NP JJ, NP -> CD NNS, CD -> '61', NNS -> 'years', JJ -> 'old', , -> ',', VP -> MD VP, MD -> 'will', VP -> VB NP PP-CLR NP-TMP, VB -> 'join', NP -> DT NN, DT -> 'the', NN -> 'board', PP-CLR -> IN NP, IN -> 'as', NP -> DT JJ NN, DT -> 'a', JJ -> 'nonexecutive', NN -> 'director', NP-TMP -> NNP CD, NNP -> 'Nov.', CD -> '29', . -> '.']
#
# First production...
# S -> NP-SBJ VP .
#
# Left hand side of first production...
# S
#
# Second production...
# NP-SBJ -> NP , ADJP ,
#
# Right hand side of second production...
# (NP, ,, ADJP, ,)

# %% [markdown]
# # (a) Preprocessing
#
# ### Removing Cross-References
#
# This first step of preprocessing takes the treebank, strips out the cross references (NPs are wrapped by special nodes that assign index numbers to them so that coreferences can be indicated).  Unfortunately, this also injects a NP-SBJ-# node between nodes you'd expect to produce one another.  Since the # changes throughout the corpus, our counts of the production rules all end up being 1 - and useless.
#
# See NP-SBJ-1 in the tree below.  Note there is also a NP-SBJ leading to a NONE/1 subtree as a crossreference later.
#
# In the code below we skip over nodes whose label start with NP-, connecting any children nodes to the NP-'s parent.  We also snip out any subtrees rooted by NONE.  The tree above is printed again after this next cell to illustrate the effect of this code.
#
# ### Chomsky Normal Form
#
# Finally, CKY assumes that trees are constructed from a grammar that is in [Chomsky normal form](https://en.wikipedia.org/wiki/Chomsky_normal_form).
#
# This means that the grammar only consists of three types of rules:
# - **Binary nonterminal:** `A -> B C`
# - **Unary preterminal:** `A -> a`
# - **Epsilon:** `A -> `$\ \ \epsilon$
#
# where `A`, `B`, and `C`, are non-terminals, `a` is a terminal, and $\epsilon$ is the empty sentence.
#
# In order to accomplish this, we add new non-terminals to the language and build longer sequences of non-terminals through them.
# For example, the ternary rule
# - `A -> B C D`
#
# becomes two rules:
# - `A -> B A|<C-D>`
# - `A|<C-D> -> C D`
#
# where `A|<C-D>` is a dummy symbol that we add to signifiy that it's a production of `A` that creates `C D`.
#
# Since the resulting tree is (at most) binary, we sometimes call this process _binarization_.
#
# #### Horizontal Markovization
#
# The dummy-symbol system works well until you get very long grammar rules such as
# - `A -> B C D E F G H I J K L`
#
# If we followed the rule above, we'd get intermediate symbols that look like `A|<B-C-D-E-F-G-H-...>`. This would quickly lead to an explosion in the number of symbols in our grammar! Because such long productions are fairly rare, we may have trouble getting good estimates of their probability. (*Recall the sparsity problem from Week 2!*)
#
# One way to counter this is called _horizontal Markovization_. Similar to how in language modeling, we "forgot" all history more than (n-1) words back, we can simply choose to truncate the the history and only store shorter symbols like `A|<B-C>`, `A|<C-D>`, `A|<D-E>`, and so on. This way, we can share parameters across more examples that are similar in structure.
#
# NLTK implements this for us in the `chomsky_normal_form` function; try changing the **`horzMarkov`** parameter below to see how it works.
#
# Take a minute to play with the ```horzMarkov``` parameter in the block below to see how this works.

# %%
sentence = corpus.parsed_sents()[35]
# Filter out NP-* nodes.
cleaned_sentence = part2_helpers.clean_tree(sentence, simplify=True)
# Convert sentence to Chomsky normal form.
cnf_sentence = copy.deepcopy(cleaned_sentence)
nltk.treetransforms.chomsky_normal_form(cnf_sentence, horzMarkov=2)
display(HTML(treeviz.render_tree(cleaned_sentence, title="Original", format='svg')))
display(HTML(treeviz.render_tree(cnf_sentence, title="Binarized (CNF)", format='svg')))
# Out:
# <h4>Original</h4>
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="1345pt" height="692pt"
#  viewBox="0.00 0.00 1345.00 692.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 688)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-688 1341,-688 1341,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <g id="a_node1"><a xlink:title="(S
#  &#160;(NN Compound)
#  &#160;(NNS yields)
#  &#160;(VP
#  &#160;&#160;&#160;(VBP assume)
#  &#160;&#160;&#160;(UCP
#  &#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN reinvestment))
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN of)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NNS dividends))))
#  &#160;&#160;&#160;&#160;&#160;(CC and)
#  &#160;&#160;&#160;&#160;&#160;(SBAR
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN that)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(S
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT the)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(JJ current)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN yield)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VBZ continues)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN for)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT a)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN year))))))))
#  &#160;(. .))">
# <ellipse fill="none" stroke="black" cx="186" cy="-666" rx="27" ry="18"/>
# <text text-anchor="middle" x="186" y="-662.3" font-family="Times,serif" font-size="14.00">S</text>
# </a>
# </g>
# </g>
# <!-- 1 -->
# <g id="node3" class="node"><title>1</title>
# <g id="a_node3"><a xlink:title="(NN Compound)">
# <ellipse fill="none" stroke="black" cx="98" cy="-522" rx="27.0966" ry="18"/>
# <text text-anchor="middle" x="98" y="-518.3" font-family="Times,serif" font-size="14.00">NN</text>
# </a>
# </g>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M172.302,-650.421C163.073,-640.16 150.989,-625.84 142,-612 128.93,-591.876 117.062,-567.318 108.955,-549.101"/>
# <polygon fill="black" stroke="black" points="112.061,-547.467 104.854,-539.701 105.645,-550.266 112.061,-547.467"/>
# </g>
# <!-- 3 -->
# <g id="node8" class="node"><title>3</title>
# <g id="a_node8"><a xlink:title="(NNS yields)">
# <ellipse fill="none" stroke="black" cx="153" cy="-450" rx="33.2948" ry="18"/>
# <text text-anchor="middle" x="153" y="-446.3" font-family="Times,serif" font-size="14.00">NNS</text>
# </a>
# </g>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g id="edge3" class="edge"><title>0&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M183.355,-647.849C177.647,-610.832 164.131,-523.181 157.223,-478.386"/>
# <polygon fill="black" stroke="black" points="160.641,-477.582 155.657,-468.232 153.722,-478.649 160.641,-477.582"/>
# </g>
# <!-- 5 -->
# <g id="node13" class="node"><title>5</title>
# <g id="a_node13"><a xlink:title="(VP
#  &#160;(VBP assume)
#  &#160;(UCP
#  &#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;(NP (NN reinvestment))
#  &#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN of)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP (NNS dividends))))
#  &#160;&#160;&#160;(CC and)
#  &#160;&#160;&#160;(SBAR
#  &#160;&#160;&#160;&#160;&#160;(IN that)
#  &#160;&#160;&#160;&#160;&#160;(S
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT the)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(JJ current)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN yield)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(VP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VBZ continues)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN for)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT a)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN year))))))))">
# <ellipse fill="none" stroke="black" cx="225" cy="-594" rx="27" ry="18"/>
# <text text-anchor="middle" x="225" y="-590.3" font-family="Times,serif" font-size="14.00">VP</text>
# </a>
# </g>
# </g>
# <!-- 0&#45;&gt;5 -->
# <g id="edge5" class="edge"><title>0&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M195.045,-648.765C199.82,-640.195 205.782,-629.494 211.127,-619.9"/>
# <polygon fill="black" stroke="black" points="214.194,-621.586 216.004,-611.147 208.079,-618.18 214.194,-621.586"/>
# </g>
# <!-- 42 -->
# <g id="node44" class="node"><title>42</title>
# <g id="a_node44"><a xlink:title="(. .)">
# <ellipse fill="none" stroke="black" cx="795" cy="-594" rx="27" ry="18"/>
# <text text-anchor="middle" x="795" y="-590.3" font-family="Times,serif" font-size="14.00">.</text>
# </a>
# </g>
# </g>
# <!-- 0&#45;&gt;42 -->
# <g id="edge42" class="edge"><title>0&#45;&gt;42</title>
# <path fill="none" stroke="black" d="M212.56,-661.947C309.811,-650.769 646.622,-612.055 758.532,-599.192"/>
# <polygon fill="black" stroke="black" points="759.109,-602.649 768.644,-598.029 758.31,-595.694 759.109,-602.649"/>
# </g>
# <!-- 2 -->
# <g id="node2" class="node"><title>2</title>
# <g id="a_node2"><a xlink:title="Compound">
# <polygon fill="none" stroke="black" points="94,-36 -7.10543e-15,-36 -7.10543e-15,-0 94,-0 94,-36"/>
# <text text-anchor="middle" x="47" y="-14.3" font-family="Times,serif" font-size="14.00">Compound</text>
# </a>
# </g>
# </g>
# <!-- 4 -->
# <g id="node4" class="node"><title>4</title>
# <g id="a_node4"><a xlink:title="yields">
# <polygon fill="none" stroke="black" points="171.5,-36 112.5,-36 112.5,-0 171.5,-0 171.5,-36"/>
# <text text-anchor="middle" x="142" y="-14.3" font-family="Times,serif" font-size="14.00">yields</text>
# </a>
# </g>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g id="edge44" class="edge"><title>2&#45;&gt;4</title>
# <path fill="none" stroke="#cccccc" d="M94.1289,-18C100.142,-18 106.155,-18 112.168,-18"/>
# <polygon fill="#cccccc" stroke="#cccccc" points="112.455,-18 112.455,-18 112.455,-18 112.455,-18"/>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge"><title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M92.4681,-504.163C84.308,-477.787 70,-424.983 70,-379 70,-379 70,-379 70,-161 70,-120.696 60.8597,-74.7758 54.1031,-46.3373"/>
# <polygon fill="black" stroke="black" points="57.4335,-45.222 51.6544,-36.3421 50.6346,-46.8877 57.4335,-45.222"/>
# </g>
# <!-- 7 -->
# <g id="node5" class="node"><title>7</title>
# <g id="a_node5"><a xlink:title="assume">
# <polygon fill="none" stroke="black" points="260.5,-36 189.5,-36 189.5,-0 260.5,-0 260.5,-36"/>
# <text text-anchor="middle" x="225" y="-14.3" font-family="Times,serif" font-size="14.00">assume</text>
# </a>
# </g>
# </g>
# <!-- 4&#45;&gt;7 -->
# <g id="edge45" class="edge"><title>4&#45;&gt;7</title>
# <path fill="none" stroke="#cccccc" d="M171.504,-18C177.401,-18 183.298,-18 189.194,-18"/>
# <polygon fill="#cccccc" stroke="#cccccc" points="189.475,-18 189.475,-18 189.475,-18 189.475,-18"/>
# </g>
# <!-- 12 -->
# <g id="node6" class="node"><title>12</title>
# <g id="a_node6"><a xlink:title="reinvestment">
# <polygon fill="none" stroke="black" points="391,-36 279,-36 279,-0 391,-0 391,-36"/>
# <text text-anchor="middle" x="335" y="-14.3" font-family="Times,serif" font-size="14.00">reinvestment</text>
# </a>
# </g>
# </g>
# <!-- 7&#45;&gt;1
# <h4>Binarized (CNF)</h4>
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="1345pt" height="1052pt"
#  viewBox="0.00 0.00 1345.00 1052.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1048)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-1048 1341,-1048 1341,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <g id="a_node1"><a xlink:title="(S
#  &#160;(NN Compound)
#  &#160;(S|&lt;NNS&#45;VP&gt;
#  &#160;&#160;&#160;(NNS yields)
#  &#160;&#160;&#160;(S|&lt;VP&#45;.&gt;
#  &#160;&#160;&#160;&#160;&#160;(VP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(VBP assume)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(UCP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;reinvestment))
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN of)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NNS
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;dividends))))
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(UCP|&lt;CC&#45;SBAR&gt;
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(CC and)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(SBAR
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN that)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(S
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT the)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(S|&lt;JJ&#45;NN&gt;
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(JJ
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;current)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(S|&lt;NN&#45;VP&gt;
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;yield)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VBZ
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;continues)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;for)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;a)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;year)))))))))))
#  &#160;&#160;&#160;&#160;&#160;(. .))))">
# <ellipse fill="none" stroke="black" cx="97" cy="-1026" rx="27" ry="18"/>
# <text text-anchor="middle" x="97" y="-1022.3" font-family="Times,serif" font-size="14.00">S</text>
# </a>
# </g>
# </g>
# <!-- 1 -->
# <g id="node3" class="node"><title>1</title>
# <g id="a_node3"><a xlink:title="(NN Compound)">
# <ellipse fill="none" stroke="black" cx="47" cy="-666" rx="27.0966" ry="18"/>
# <text text-anchor="middle" x="47" y="-662.3" font-family="Times,serif" font-size="14.00">NN</text>
# </a>
# </g>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M86.1064,-1009.44C79.4141,-999.216 71.1625,-985.319 66,-972 51.3818,-934.287 47,-923.447 47,-883 47,-883 47,-883 47,-809 47,-768.996 47,-722.653 47,-694.08"/>
# <polygon fill="black" stroke="black" points="50.5001,-694.049 47,-684.049 43.5001,-694.049 50.5001,-694.049"/>
# </g>
# <!-- 3 -->
# <g id="node8" class="node"><title>3</title>
# <g id="a_node8"><a xlink:title="(S|&lt;NNS&#45;VP&gt;
#  &#160;(NNS yields)
#  &#160;(S|&lt;VP&#45;.&gt;
#  &#160;&#160;&#160;(VP
#  &#160;&#160;&#160;&#160;&#160;(VBP assume)
#  &#160;&#160;&#160;&#160;&#160;(UCP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN reinvestment))
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN of)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NNS dividends))))
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;(UCP|&lt;CC&#45;SBAR&gt;
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(CC and)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(SBAR
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN that)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(S
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(DT the)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(S|&lt;JJ&#45;NN&gt;
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(JJ current)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(S|&lt;NN&#45;VP&gt;
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NN yield)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(VBZ
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;continues)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(PP
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(IN
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;for)
#  &#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;&#160;(NP
#  &#160;&#160;

# %% [markdown]
# ### Run Pre-Processing on Corpus
#
# We'll loop through the whole corpus, and make copies of each sentence in CNF form. Use the `cnf_sentences` list for training the grammar in part (b).
#
# **Note:** if you're using the `treebank` corpus sample, this should run in just a few seconds. But if you use the full Penn Treebank, it'll take around 1-2 minutes to process all the trees. If you get an error "`AttributeError: 'tqdm' object has no attribute 'miniters'`", ignore it - the code should still work.

# %%
# Preprocess the treebank.
cleaned_sentences = []
cnf_sentences = []
for sentence in ProgressBar(corpus.parsed_sents(), desc="Processing sentences"):
    # Filter out NP-* nodes.
    cleaned_sentence = part2_helpers.clean_tree(sentence, simplify=True)
    cleaned_sentences.append(cleaned_sentence)
    
    # Convert sentence to Chomsky normal form.
    cnf_sentence = copy.deepcopy(cleaned_sentence)
    nltk.treetransforms.chomsky_normal_form(cnf_sentence, horzMarkov=2)
    cnf_sentences.append(cnf_sentence)
# Out:
# Processing sentences: 100%|██████████| 3914/3914 [00:07<00:00, 537.95it/s]

# %% [markdown]
# # (b) Production rule probabilities
#
# In this next section, you'll compute about production rule probabilities.
#
# We won't use epsilon rules, so all of our rules will be of the form:
# - Binary nonterminal: `A -> B C`
# - Unary preterminal: `A -> a`
#
# The left hand side (LHS) of these rules only ever consist of a single nonterminal.  The right hand side (RHS) consists of either two non-terminals or one terminal.
#
# We'll do this in two stages:
# - Count LHS, and (LHS,RHS) each in their own dict
# - Calculate $ P(RHS | LHS) = \frac{count(LHS, RHS)}{count(LHS)} $

# %% [markdown]
# ## Part (b) Implementation: Training the grammar
#
# Now that you're comfortable with NLTK Tree objects, let's use them to build our grammar. We've implemented a skeleton in **`pcfg.py`**; your job is to finish the implementation of the `pcfg.PCFG` class. Specifically:
#
# - Implement `update_counts`, which updates the production counts for a single sentence.
# - Implement `compute_scores`, which computes log-probabilities.
#
# Read the documentation in `pcfg.py` for the names of the data structures you should populate, and their precise types. Both functions should be straightforward, and only require a couple of lines of code each!
#
# #### Indexing Rules
#
# Your code here need only deal with straightforward maps of productions, but in order to parse efficiently we need to build an inverted index, keyed on the rule's RHS. This way, we can quickly look up rules (and their scores) that would combine two subtrees during the CKY algorithm.
#
# We've implemented this for you in `pcfg.PCFG.build_index()`, but you'll want to look carefully at how that function works - when you implement CKY in part(c), you'll make heavy use of the `grammar.parsing_index` structure.
#
# ### Testing `update_counts()`
#
# If everything works, you should see this in the cell below:
#
# ```
# Top productions:
# (, -> ',', 4885)
# (PP -> IN NP, 4045)
# (DT -> 'the', 4038)
# (. -> '.', 3828)
# (S|<VP-.> -> VP ., 3018)
# (IN -> 'of', 2319)
# (NP -> NP PP, 2188)
# (TO -> 'to', 2161)
# (NP -> DT NN, 2020)
# (DT -> 'a', 1874)
# ```
#
# ### Testing `compute_scores()`
#
# If everything went well, you should see:
# ```
# food [(NN, -6.71280430578804)]
# a [(IN, -9.19593714166544), (DT, -1.4717815426061982), (LS, -2.5649493574615367), (JJ, -7.978310969867721)]
# I [(NNP, -8.45638105201948), (PRP, -2.720363461335567)]
# ```

# %%
reload(pcfg)
reload(pcfg_test)
unittest.TextTestRunner(verbosity=2).run(
    unittest.TestLoader().loadTestsFromName(
        'TestPCFG', pcfg_test))
# Out:
# test_pcfg (pcfg_test.TestPCFG) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %%
reload(pcfg)

grammar = pcfg.PCFG()
for sentence in ProgressBar(cnf_sentences, desc="Counting productions"):
    grammar.update_counts(sentence)
    
print "Top productions:"
for p in grammar.top_productions():  # Top productions, by un-normalized count
    print p
print ""

grammar.compute_scores()  # compute log-probabilities
grammar.build_index()     # prepare for parsing

for w in ['food', 'a', 'I']:
    print w, grammar.parsing_index[(w,)]
# Out:
# Counting productions: 100%|██████████| 3914/3914 [00:02<00:00, 1665.70it/s]
# Top productions:
# (PP -> IN NP, 7369)
# (, -> ',', 4885)
# (DT -> 'the', 4038)
# (. -> '.', 3828)
# (S|<VP-.> -> VP ., 3071)
# (NP -> NP PP, 2644)
# (S -> VP, 2335)
# (IN -> 'of', 2319)
# (TO -> 'to', 2161)
# (NP -> DT NN, 2020)
#
# food [(NN, -6.7128043057880404)]
# a [(LS, -2.5649493574615367), (JJ, -7.9783109698677208), (DT, -1.4717815426061982), (IN, -9.1959371416654392)]
# I [(NNP, -8.4563810520194806), (PRP, -2.7203634613355669)]

# %% [markdown]
# You don't need to do anything with this next cell except to run it.
#
# It's not particularly useful, but if you need to keep track of what each variable contains, this provides a useful reference.

# %%
print 'Productions (nltk.grammar.Production):'
for (production, count) in grammar.production_counts.most_common(5):
    print (production, count)

print '\n\nLHS counts:'
for (lhs, count) in grammar.lhs_counts.most_common(5):
    print (lhs, count)
    
print '\n\nLog Probabilities:'
print '\n'.join([str(x) for x in grammar.parsing_index.iteritems()][0:10])
# Out:
# Productions (nltk.grammar.Production):
# (PP -> IN NP, 7369)
# (, -> ',', 4885)
# (DT -> 'the', 4038)
# (. -> '.', 3828)
# (S|<VP-.> -> VP ., 3071)
#
#
# LHS counts:
# (NP, 23766)
# (VP, 14524)
# (NN, 13166)
# (S, 9946)
# (IN, 9857)
#
#
# Log Probabilities:
# ((u'truce',), [(NN, -8.3867807393597129)])
# ((VBD, VP|<RB-S>), [(VP, -9.583557732534226)])
# ((u'trimmed',), [(VBN, -7.6657534318616989)])
# ((JJ, S|<NN-PRP>), [(S|<JJ-NN>, -5.4424177105217932)])
# ((u'iota',), [(NN, -9.485393028027822)])
# ((u'unitholders',), [(NNS, -8.7073175602732125)])
# ((u'resolve',), [(VB, -6.7468037479243748)])
# ((u'waited',), [(VBD, -8.0205991498969702)])
# ((PRN, S|<,-NNP>), [(S|<PRN-,>, -2.0794415416798357)])
# ((u'Lehman',), [(NNP, -7.3577687633513715)])

# %% [markdown]
# # (c) Implement CKY
#
# After that bit of preamble, you only have one more task to go!  It's a big one though, so do take your time and get things right.
#
# **In `cky.py`, implement the `CKY_apply_preterminal_rules` and `CKY_apply_binary_rules` functions.**
#
# We've set up the skeleton of the CKY algorithm for you in the `CKY` function; be sure to read the in-line comments there carefully before you start. The outline is:
# 1. Construct the chart (`make_chart`, provided)
# 2. Populate the first row of the chart using preterminal rules (`CKY_apply_preterminal_rules`)
# 3. Populate the rest of the chart using binary rules (`CKY_apply_binary_rules`)
# 4. Read off the top cell for the final derivation. (provided)
#
# We'll implement the chart itself as a dict that you can index into first by cell position and then by non-terminal like this:
# ```
# chart[(0, 1)][NN]
# ```
#
# The value is an [nltk.tree.ProbabilisticTree](http://www.nltk.org/api/nltk.html#nltk.tree.ProbabilisticTree), which is just like an `nltk.tree.Tree` except that it has an additional `logprob()` method that returns the score (log-probability). Similarly, the constructor takes an additional argument: `pt = ProbabilisticTree(lhs, (rhs_1,...), logprob=score)` - you should use this to construct the backtrace trees.
#
# See the in-line comments in `cky.py` for additional hints and advice.

# %%
reload(cky)
reload(cky_test)
unittest.TextTestRunner(verbosity=2).run(
    unittest.TestLoader().loadTestsFromName(
        'TestParsing', cky_test))
# Out:
# test_failing_rule_application (cky_test.TestParsing) ... ok
# test_rule_application (cky_test.TestParsing) ... ok
# test_rule_application_three_words (cky_test.TestParsing) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.004s
#
# OK
# <unittest.runner.TextTestResult run=3 errors=0 failures=0>

# %%
reload(cky)
parser = cky.CKYParser(grammar)
derivation = parser.parse('I eat red hot food with a knife'.split(), 'S')

assert round(derivation.logprob(), 2) == -64.08
derivation
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(PRP, ['I']) (p=0.15173612851696769), ProbabilisticTree(VP, [ProbabilisticTree(VBP, ['eat']) (p=0.0068668096876260687), ProbabilisticTree(VP|<NP-PP>, [ProbabilisticTree(NP, [ProbabilisticTree(JJ, ['red']) (p=0.0039654190017090543), ProbabilisticTree(NP|<JJ-NN>, [ProbabilisticTree(JJ, ['hot']) (p=0.0039654190017090543), ProbabilisticTree(NN, ['food']) (p=0.0095333282960814777)]) (p=3.2078091828121638e-05)]) (p=1.9662155367311963e-09), ProbabilisticTree(PP, [ProbabilisticTree(IN, ['with']) (p=0.10602582040574654), ProbabilisticTree(NP, [ProbabilisticTree(DT, ['a']) (p=0.36053680734251442), ProbabilisticTree(NN, ['knife']) (p=0.0013951219699423914)]) (p=9.1090931043064175e-05)]) (p=8.1464414595723497e-06)]) (p=1.3501972707728444e-14)]) (p=1.8692043100608051e-18)]) (p=5.1222272930921724e-20)

# %% [markdown]
# ### Experimentation
#
# Try a few more sentences.  Do you notice any patterns with your results?  Any common types of errors?  Are these an artifact of CKY, or of how you did the markovization/counting?
#
# Put any code you write in the next cell and a writeup of the results in the cell after.
#
# (If you have a format that's more natural to your description, feel free to deviate from this format.)

# %%
#### YOUR CODE HERE ####

#parser.parse('I eat some food'.split(), 'S')
parser.parse('I touched the walls with a hook'.split(), 'S')

#### END(YOUR CODE) ####
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(PRP, ['I']) (p=0.15173612851696769), ProbabilisticTree(VP, [ProbabilisticTree(VBD, ['touched']) (p=0.0038508719063050259), ProbabilisticTree(VP|<NP-PP>, [ProbabilisticTree(NP, [ProbabilisticTree(DT, ['the']) (p=0.61382222719119828), ProbabilisticTree(NNS, ['walls']) (p=0.0023924134349197239)]) (p=8.0151939296945059e-05), ProbabilisticTree(PP, [ProbabilisticTree(IN, ['with']) (p=0.10602582040574654), ProbabilisticTree(NP, [ProbabilisticTree(DT, ['a']) (p=0.36053680734251442), ProbabilisticTree(NN, ['hook']) (p=0.0022556425095938077)]) (p=0.00014727642509113265)]) (p=1.3171220906862798e-05)]) (p=8.8989389984796029e-10)]) (p=2.0572450879918658e-13)]) (p=5.6375201370838937e-15)

# %%
parser.parse('I touched the walls with a thing'.split(), 'S')
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(PRP, ['I']) (p=0.15173612851696769), ProbabilisticTree(VP, [ProbabilisticTree(VBD, ['touched']) (p=0.0038508719063050259), ProbabilisticTree(VP|<NP-PP>, [ProbabilisticTree(NP, [ProbabilisticTree(DT, ['the']) (p=0.61382222719119828), ProbabilisticTree(NNS, ['walls']) (p=0.0023924134349197239)]) (p=8.0151939296945059e-05), ProbabilisticTree(PP, [ProbabilisticTree(IN, ['with']) (p=0.10602582040574654), ProbabilisticTree(NP, [ProbabilisticTree(DT, ['a']) (p=0.36053680734251442), ProbabilisticTree(NN, ['thing']) (p=0.0086905566399896571)]) (p=0.0005674277322518475)]) (p=5.0746180222290479e-05)]) (p=3.4285899947871707e-09)]) (p=7.9261695430422166e-13)]) (p=2.1720280519643278e-14)

# %%
parser.parse('I touched the walls with a ball'.split(), 'S')
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(PRP, ['I']) (p=0.15173612851696769), ProbabilisticTree(VP, [ProbabilisticTree(VBD, ['touched']) (p=0.0038508719063050259), ProbabilisticTree(VP|<NP-PP>, [ProbabilisticTree(NP, [ProbabilisticTree(DT, ['the']) (p=0.61382222719119828), ProbabilisticTree(NNS, ['walls']) (p=0.0023924134349197239)]) (p=8.0151939296945059e-05), ProbabilisticTree(PP, [ProbabilisticTree(IN, ['with']) (p=0.10602582040574654), ProbabilisticTree(NP, [ProbabilisticTree(DT, ['a']) (p=0.36053680734251442), ProbabilisticTree(NN, ['ball']) (p=0.0013951219699423914)]) (p=9.1090931043064175e-05)]) (p=8.1464414595723497e-06)]) (p=5.504021693664441e-10)]) (p=1.2724125421498468e-13)]) (p=3.4868238942059545e-15)

# %% [markdown]
# #### Word meanings are not considered
# In these cases such as 'I touched the walls with a thing', it should be unlikely that the walls have a thing and that's how I'm identifying them.  Because of the bottom-up approach of the CKY algorithm, it assumes that whatever phrase is at the end refers to the walls, because it is the smallest possible sub-group that works.

# %%
parser.parse('The flies fly after the elephant'.split(), 'S')
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(DT, ['The']) (p=0.18452259796200876), ProbabilisticTree(VP, [ProbabilisticTree(VBZ, ['flies']) (p=0.0049391308960821667), ProbabilisticTree(VP, [ProbabilisticTree(VB, ['fly']) (p=0.0043480491485015085), ProbabilisticTree(PP, [ProbabilisticTree(IN, ['after']) (p=0.034622849618191592), ProbabilisticTree(NP, [ProbabilisticTree(DT, ['the']) (p=0.61382222719119828), ProbabilisticTree(NN, ['elephant']) (p=0.0013951219699423914)]) (p=0.00015508441033221593)]) (p=4.5291020972436294e-06)]) (p=9.0607296193517385e-10)]) (p=4.0822850098462625e-13)]) (p=1.4406145060014003e-15)

# %%
parser.parse('The flies eat stuff'.split(), 'S')
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(DT, ['The']) (p=0.18452259796200876), ProbabilisticTree(VP, [ProbabilisticTree(VBZ, ['flies']) (p=0.0049391308960821667), ProbabilisticTree(VP, [ProbabilisticTree(VBP, ['eat']) (p=0.0068668096876260687), ProbabilisticTree(NN, ['stuff']) (p=0.0013951219699423914)]) (p=1.2486158580827112e-08)]) (p=5.6256019268259181e-12)]) (p=1.9852420203948598e-14)

# %%
parser.parse('The people eat stuff'.split(), 'S')
# Out:
# ProbabilisticTree(S, [ProbabilisticTree(DT, ['The']) (p=0.18452259796200876), ProbabilisticTree(S|<NNS-VP>, [ProbabilisticTree(NNS, ['people']) (p=0.038957208937773553), ProbabilisticTree(VP, [ProbabilisticTree(VBP, ['eat']) (p=0.0068668096876260687), ProbabilisticTree(NN, ['stuff']) (p=0.0013951219699423914)]) (p=1.2486158580827112e-08)]) (p=2.9102087722919727e-10)]) (p=2.5275034543689275e-12)

# %% [markdown]
# #### The word after a determiner should be a noun.
# This doesn't look like a problem with the CKY algorithm, but an issue with the counting.  At first I thought there must be sentences that are marked as having verbs after determiners, but that didn't make sense!  I looked at the sentences in the corpus below and didn't see any examples of DT to VP, so it must be that "flies" was only seen as a verb, so it was just a problem of limited vocabulary stumping the algorithm.

# %%
for i in range(1000):
    #print corpus.sents()[i]

    if corpus.tagged_sents()[i][0][1] == 'DT':
        print corpus.tagged_sents()[i][0] + corpus.tagged_sents()[i][1]
        print "\n"
# Out:
# (u'A', u'DT', u'form', u'NN')
#
#
# (u'The', u'DT', u'asbestos', u'NN')
#
#
# (u'A', u'DT', u'Lorillard', u'NNP')
#
#
# (u'Neither', u'DT', u'Lorillard', u'NNP')
#
#
# (u'The', u'DT', u'Lorillard', u'NNP')
#
#
# (u'The', u'DT', u'total', u'NN')
#
#
# (u'The', u'DT', u'percentage', u'NN')
#
#
# (u'The', u'DT', u'plant', u'NN')
#
#
# (u'The', u'DT', u'finding', u'NN')
#
#
# (u'The', u'DT', u'U.S.', u'NNP')
#
#
# (u'The', u'DT', u'average', u'JJ')
#
#
# (u'The', u'DT', u'average', u'JJ')
#
#
# (u'The', u'DT', u'yield', u'NN')
#
#
# (u'The', u'DT', u'top', u'JJ')
#
#
# (u'The', u'DT', u'average', u'JJ')
#
#
# (u'The', u'DT', u'30-day', u'JJ')
#
#
# (u'The', u'DT', u'thrift', u'NN')
#
#
# (u'The', u'DT', u'federal', u'JJ')
#
#
# (u'The', u'DT', u'government', u'NN')
#
#
# (u'The', u'DT', u'House', u'NNP')
#
#
# (u'The', u'DT', u'Treasury', u'NNP')
#
#
# (u'The', u'DT', u'National', u'NNP')
#
#
# (u'The', u'DT', u'idea', u'NN')
#
#
# (u'The', u'DT', u'next', u'JJ')
#
#
# (u'The', u'DT', u'governor', u'NN')
#
#
# (u'A', u'DT', u'buffet', u'NN')
#
#
# (u'This', u'DT', u'time', u'NN')
#
#
# (u'The', u'DT', u'new', u'JJ')
#
#
# (u'A', u'DT', u'full', u'JJ')
#
#
# (u'The', u'DT', u'magazine', u'NN')
#
#
# (u'Both', u'DT', u'Newsweek', u'NNP')
#
#
# (u'The', u'DT', u'move', u'NN')
#
#
# (u'No', u'DT', u'matter', u'NN')
#
#
# (u'The', u'DT', u'fact', u'NN')
#
#
# (u'The', u'DT', u'refund', u'NN')
#
#
# (u'The', u'DT', u'exact', u'JJ')
#
#
# (u'A', u'DT', u'Commonwealth', u'NNP')
#
#
# (u'The', u'DT', u'$', u'$')
#
#
# (u'The', u'DT', u'Illinois', u'NNP')
#
#
# (u'The', u'DT', u'utility', u'NN')
#
#
# (u'The', u'DT', u'commission', u'NN')
#
#
# (u'The', u'DT', u'strong', u'JJ')
#
#
# (u'The', u'DT', u'monthly', u'JJ')
#
#
# (u'The', u'DT', u'new', u'JJ')
#
#
# (u'The', u'DT', u'plant', u'NN')
#
#
# (u'The', u'DT', u'survival', u'NN')
#
#
# (u'The', u'DT', u'documents', u'NNS')
#
#
# (u'The', u'DT', u'documents', u'NNS')
#
#
# (u'The', u'DT', u'filing', u'NN')
#
#
# (u'The', u'DT', u'SEC', u'NNP')
#
#
# (u'The', u'DT', u'spinoff', u'NN')
#
#
# (u'The', u'DT', u'new', u'JJ')
#
#
# (u'No', u'DT', u'price', u'NN')
#
#
# (u'All', u'DT', u'came', u'VBD')
#
#
# (u'The', u'DT', u'U.S.', u'NNP')
#
#
# (u'That', u'DT', u'measure', u'NN')
#
#
# (u'These', u'DT', u'three', u'CD')
#
#
# (u'Those', u'DT', u'countries', u'NNS')
#
#
# (u'The', u'DT', u'1988', u'CD')
#
#
# (u'The', u'DT', u'declaration', u'NN')
#
#
# (u'The', u'DT', u'Latin', u'NNP')
#
#
# (u'That', u'DT', u'year', u'NN')
#
#
# (u'The', u'DT', u'computers', u'NNS')
#
#
# (u'That', u'DT', u'stake', u'NN')
#
#
# (u'The', u'DT', u'field', u'NN')
#
#
# (u'The', u'DT', u'Perch', u'NNP')
#
#
# (u'The', u'DT', u'sale', u'NN')
#
#
# (u'The', u'DT', u'White', u'NNP')
#
#
# (u'The', u'DT', u'action', u'NN')
#
#
# (u'The', u'DT', u'White', u'NNP')
#
#
# (u'An', u'DT', u'ambitious', u'JJ')
#
#
# (u'The', u'DT', u'company', u'NN')
#
#
# (u'The', u'DT', u'company', u'NN')
#
#
# (u'Neither', u'DT', u'they', u'PRP')
#
#
# (u'The', u'DT', u'purchases', u'NNS')
#
#
# (u'The', u'DT', u'rest', u'NN')
#
#
# (u'That', u'DT', u'fund', u'NN')
#
#
# (u'The', u'DT', u'latest', u'JJS')
#
#
# (u'The', u'DT', u'new', u'JJ')
#
#
# (u'The', u'DT', u'company', u'NN')
#
#
# (u'The', u'DT', u'offer', u'NN')
#
#
# (u'The', u'DT', u'offer', u'NN')
#
#
# (u'The', u'DT', u'total', u'NN')
#
#
# (u'The', u'DT', u'protracted', u'JJ')
#
#
# (u'The', u'DT', u'announcement', u'NN')
#
#
# (u'The', u'DT', u'turf', u'NN')
#
#
# (u'The', u'DT', u'next', u'JJ')
#
#
# (u'The', u'DT', u'recent', u'JJ')
#
#
# (u'The', u'DT', u'surge', u'NN')
#
#
# (u'These', u'DT', u'funds', u'NNS')
#
#
# (u'Another', u'DT', u'concern', u'NN')
#
#
# (u'The', u'DT', u'reason', u'NN')
#
#
# (u'The', u'DT', u'newly', u'RB')
#
#
# (u'That', u'DT', u'way', u'NN')
#
#
# (u'The', u'DT', u'U.S.', u'NNP')
#
#
# (u'The', u'DT', u'branch', u'NN')
#
#
# (u'The', u'DT', u'U.S.S.R.', u'NNP')
#
#
# (u'The', u'DT', u'State', u'NNP')
#
#
# (u'Any', u'DT', u'reading', u'NN')
#
#
# (u'The', u'DT', u'purchasing', u'VBG')
#
#
# (u'The', u'DT', u'figures', u'NNS')
#
#
# (u'A', u'DT', u'soft', u'JJ')
#
#
# (u'The', u'DT', u'department', u'NN')
#
#
# (u'The', u'DT', u'department', u'NN')
#
#
# (u'The', u'DT', u'government', u'NN')
#
#
# (u'The', u'DT', u'goverment', u'NN')
#
#
# (u'The', u'DT', u'government', u'NN')
#
#
# (u'The', u'DT', u'report', u'NN')
#
#
# (u'The', u'DT', u'purhasing', u'NN')
#
#
# (u'The', u'DT', u'decline', u'NN')
#
#
# (u'The', u'DT', u'purchasing', u'NN')
#
#
# (u'Each', u'DT', u'of', u'IN')
#
#
# (u'This', u'DT', u'is', u'VBZ')
#
#
# (u'That', u'DT', u"'s", u'VBZ')
#
#
# (u'A', u'DT', u'disaffected', u'JJ')
#
#
# (u'The', u'DT', u'40-year-old', u'JJ')
#
#
# (u'A', u'DT', u'more', u'RBR')
#
#
# (u'A', u'DT', u'player', u'NN')
#
#
# (u'Some', u'DT', u'of', u'IN')
#
#
# (u'All', u'DT', u'of', u'IN')
#
#
# (u'A', u'DT', u'marketing', u'NN')
#
#
# (u'The', u'DT', u'study', u'NN')
#
#
# (u'The', u'DT', u'survey', u'NN')
#
#
# (u'The', u'DT', u'Thai', u'NNP')
#
#
# (u'The', u'DT', u'meeting', u'NN')
#
#
# (u'A', u'DT', u'major', u'JJ')
#
#
# (u'An', u'DT', u'official', u'NN')
#
#
# (u'The', u'DT', u'PLO', u'NNP')
#
#
# (u'A', u'DT', u'Beijing', u'NNP')
#
#
# (u'The', u'DT', u'man', u'NN')
#
#
# (u'The', u'DT', u'Polish', u'JJ')
#
#
# (u'The', u'DT', u'official', u'JJ')
#
#
# (u'The', u'DT', u'Nagymaros', u'NNP')
#
#
# (u'The', u'DT', u'Czech', u'JJ')
#
#
# (u'A', u'DT', u'painting', u'NN')
#
#
# (u'The', u'DT', u'Toronto-based', u'JJ')
#
#
# (u'The', u'DT', u'warrants', u'NNS')
#
#
# (u'The', u'DT', u'issue', u'NN')
#
#
# (u'The', u'DT', u'Artist', u'NNP')
#
#
# (u'The', u'DT', u'Artist', u'NNP')
#
#
# (u'This', u'DT', u'cute', u'JJ')
#
#
# (u'The', u'DT', u'beds', u'NNS')
#
#
# (u'This', u'DT', u'story', u'NN')
#
#
# (u'The', u'DT', u'movie', u'NN')
#
#
# (u'The', u'DT', u'French', u'JJ')
#
#
# (u'The', u'DT', u'discussions', u'NNS')
#
#
# (u'The', u'DT', u'three', u'CD')
#
#
# (u'This', u'DT', u'is', u'VBZ')
#
#
# (u'The', u'DT', u'irony', u'NN')
#
#
# (u'A', u'DT', u'trend', u'NN')
#
#
# (u'The', u'DT', u'screen', u'NN')
#
#
# (u'The', u'DT', u'screen', u'NN')
#
#
# (u'The', u'DT', u'other', u'JJ')
#
#
# (u'The', u'DT', u'other', u'JJ')
#
#
# (u'The', u'DT', u'city', u'NN')
#
#
# (u'The', u'DT', u'campaign', u'NN')
#
#
# (u'The', u'DT', u'other', u'JJ')
#
#
# (u'That', u'DT', u'commercial', u'JJ')
#
#
# (u'The', u'DT', u'ad', u'NN')
#
#
# (u'The', u'DT', u'Coleman', u'NNP')
#
#
# (u'A', u'DT', u'voice', u'NN')
#
#
# (u'The', u'DT', u'legislation', u'NN')
#
#
# (u'The', u'DT', u'attacks', u'NNS')
#
#
# (u'The', u'DT', u'only', u'JJ')
#
#
# (u'A', u'DT', u'seat', u'NN')
#
#
# (u'The', u'DT', u'record', u'JJ')
#
#
# (u'The', u'DT', u'flow', u'NN')
#
#
# (u'These', u'DT', u'nations', u'NNS')
#
#
# (u'These', u'DT', u'nations', u'NNS')
#
#
# (u'The', u'DT', u'economic', u'JJ')
#
#
# (u'The', u'DT', u'Baker', u'NNP')
#
#
# (u'Some', u'DT', u'Asian', u'JJ')
#
#
# (u'The', u'DT', u'issue', u'NN')
#
#
# (u'The', u'DT', u'Senate-House', u'JJ')
#
#
# (u'The', u'DT', u'student', u'NN')
#
#
# (u'The', u'DT', u'teacher', u'NN')
#
#
# (u'The', u'DT', u'1987', u'CD')
#
#
# (u'The', u'DT', u'bonus', u'NN')
#
#
# (u'A', u'DT', u'50-state', u'JJ')
#
#
# (u'The', u'DT', u'group', u'NN')
#
#
# (u'These', u'DT', u'materials', u'NNS')
#
#
# (u'Another', u'DT', u'was', u'VBD')
#
#
# (u'Some', u'DT', u'fellow', u'JJ')
#
#
# (u'The', u'DT', u'rest', u'NN')
#
#
# (u'The', u'DT', u'last', u'JJ')
#
#
# (u'The', u'DT', u'school-board', u'NN')
#
#
# (u'The', u'DT', u'show', u'NN')
#
#
# (u'The', u'DT', u'radio', u'NN')
#
#
# (u'These', u'DT', u'days', u'NNS')
#
#
# (u'The', u'DT', u'mathematics', u'NN')
#
#
# (u'The', u'DT', u'most', u'RBS')
#
#
# (u'The', u'DT', u'materials', u'NNS')
#
#
# (u'The', u'DT', u'Sacramento-based', u'JJ')
#
#
# (u'The', u'DT', u'purchase', u'NN')
#
#
# (u'The', u'DT', u'Department', u'NNP')
#
#
# (u'Both', u'DT', u'Dr.', u'NNP')
#
#
# (u'The', u'DT', u'controversy', u'NN')
#
#
# (u'The', u'DT', u'department', u'NN')
#
#
# (u'A', u'DT', u'majority', u'NN')
#
#
# (u'The', u'DT', u'dispute', u'NN')
#
#
# (u'Some', u'DT', u'researchers', u'NNS')
#
#
# (u'The', u'DT', u'NIH', u'NNP')
#
#
# (u'The', u'DT', u'Nasdaq', u'NNP')
#
#
# (u'The', u'DT', u'Nasdaq', u'NNP')
#
#
# (u'The', u'DT', u'index', u'NN')
#
#
# (u'The', u'DT', u'bank', u'NN')
#
#
# (u'The', u'DT', u'two', u'CD')
#
#
# (u'The', u'DT', u'stocks', u'NNS')
#
#
# (u'The', u'DT', u'biggest', u'JJS')
#
#
# (u'The', u'DT', u'Stamford', u'NNP')
#
#
# (u'Another', u'DT', u'OTC', u'NNP')
#
#
# (u'The', u'DT', u'Pennsylvania', u'NNP')
#
#
# (u'The', u'DT', u'two', u'CD')
#
#
# (u'The', u'DT', u'restaurant', u'NN')
#
#
# (u'The', u'DT', u'fast-food', u'NN')
#
#
# (u'The', u'DT', u'Huntsville', u'NNP')
#
#
# (u'The', u'DT', u'Internal', u'NNP')
#
#
# (u'The', u'DT', u'warnings', u'NNS')
#
#
# (u'The', u'DT', u'IRS', u'NNP')
#
#
# (u'The', u'DT', u'form', u'NN')
#
#
# (u'These', u'DT', u'individuals', u'NNS')
#
#
# (u'The', u'DT', u'defense', u'NN')
#
#
# (u'The', u'DT', u'American', u'NNP')
#
#
# (u'A', u'DT', u'spokesman', u'NN')
#
#
# (u'Some', u'DT', u'criminal', u'JJ')
#
#
# (u'THE', u'DT', u'WAR', u'NN')
#
#
# (u'The', u'DT', u'reason', u'NN')
#
#
# (u'The', u'DT', u'judge', u'NN')
#
#
# (u'The', u'DT', u'dispute', u'NN')
#
#
# (u'The', u'DT', u'guild', u'NN')
#
#
# (u'A', u'DT', u'spokesman', u'NN')
#
#
# (u'A', u'DT', u'federal', u'JJ')
#
#
# (u'A', u'DT', u'Department', u'NNP')
#
#
# (u'The', u'DT', u'rule', u'NN')
#
#
# (u'The', u'DT', u'panel', u'NN')
#
#
# (u'The', u'DT', u'judge', u'NN')
#
#
# (u'The', u'DT', u'report', u'NN')
#
#
# (u'The', u'DT', u'first', u'JJ')
#
#
# (u'This', u'DT', u'trial', u'NN')
#
#
# (u'A', u'DT', u'former', u'JJ')
#
#
# (u'The', u'DT', u'tire', u'NN')
